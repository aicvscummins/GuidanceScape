# %%
import mysql.connector
from tkinter import *
import tkinter as tk
from tkinter import messagebox


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="ponchu@01",
  database="journaling"
)
mycursor = mydb.cursor()

# %%
def insert_user_info():
    name=Name.get()
    age=Age.get()
    user_name=User_name.get()
    password=Pass.get()
    insertU = "insert into user_information (name,age,user_name,password) values (%s,%s,%s,%s)"
    val=(name,age,user_name,password)
    
    try:
        mycursor.executemany(insertU,(val,))
        mydb.commit()
        messagebox.showinfo('Success',"Successful sign up")
    except:
        messagebox.showinfo("Error","Can't add data into Database")

        
def insert_diary():
    date=Date.get()
    diary_ent=diary.get()
    user_name=User.get()
    password=Passw.get()
    insertU = "insert into diary (user_name,password,date,diary_entry) values (%s,%s,%s,%s)"
    val=(user_name,password,date,diary_ent)
    
    try:
        mycursor.executemany(insertU,(val,))
        mydb.commit()
        messagebox.showinfo('Success',"Entry has been made")
    except:
        messagebox.showinfo("Error","Sorry could not enter")
        

    
    
    
def new_ent():
    global User,Passw,Date,root,diary
    
    root = tk.Tk()
    root.title("New Entry")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")



    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="salmon")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="cyan2",bd=5)
    headingFrame1.place(relx=0.25,rely=0.05,relwidth=0.5,relheight=0.10)

    headingLabel = Label(headingFrame1, text="New Entry", fg='black', font=('Courier',30))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='cyan2')
    labelFrame.place(relx=0.1,rely=0.17,relwidth=0.8,relheight=0.7)
    
    #user Name
    User= Label(labelFrame,text="User Name : ", bg='black', fg='white')
    User.place(relx=0.05,rely=0.1, relheight=0.08)
        
    User = Entry(labelFrame)
    User.place(relx=0.3,rely=0.1, relwidth=0.62, relheight=0.08)
    
    
    
     # password
    Passw= Label(labelFrame,text="Password : ", bg='black', fg='white')
    Passw.place(relx=0.05,rely=0.3, relheight=0.08)
        
    Passw = Entry(labelFrame)
    Passw.place(relx=0.3,rely=0.3, relwidth=0.62, relheight=0.08)
    
    
     #date
    Date= Label(labelFrame,text="Date ", bg='black', fg='white')
    Date.place(relx=0.05,rely=0.5, relheight=0.08)

    Date = Entry(labelFrame)
    Date.place(relx=0.3,rely=0.5, relwidth=0.62, relheight=0.08)
    
    
    #diary_entry
    diary= Label(labelFrame,text="Entry ", bg='black', fg='white')
    diary.place(relx=0.05,rely=0.7, relheight=0.08)

    diary = Entry(labelFrame)
    diary.place(relx=0.3,rely=0.7, relwidth=0.62, relheight=0.3)
    
    submitb=tk.Button(root,text='Diary Entry',command=insert_diary)
    submitb.place(relx=0.2,rely=0.83, relwidth=0.4, relheight=0.08)
    
    quitb=tk.Button(root,text='Quit',command=root.destroy)
    quitb.place(relx=0.5,rely=0.83, relwidth=0.4, relheight=0.08)


def sign_up():
    global Name,Age,User_name,Pass,root
    
    root = tk.Tk()
    root.title("Signup")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")



    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="salmon")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="cyan2",bd=5)
    headingFrame1.place(relx=0.25,rely=0.05,relwidth=0.5,relheight=0.10)

    headingLabel = Label(headingFrame1, text="Information", fg='black', font=('Courier',30))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='cyan2')
    labelFrame.place(relx=0.1,rely=0.17,relwidth=0.8,relheight=0.7)
    
    #Name
    Name= Label(labelFrame,text="Name : ", bg='black', fg='white')
    Name.place(relx=0.05,rely=0.1, relheight=0.08)
        
    Name = Entry(labelFrame)
    Name.place(relx=0.3,rely=0.1, relwidth=0.62, relheight=0.08)
    
    
     # age
    Age= Label(labelFrame,text="Age : ", bg='black', fg='white')
    Age.place(relx=0.05,rely=0.3, relheight=0.08)
        
    Age = Entry(labelFrame)
    Age.place(relx=0.3,rely=0.3, relwidth=0.62, relheight=0.08)
    
    
     # user_name
    User_name= Label(labelFrame,text="Username : ", bg='black', fg='white')
    User_name.place(relx=0.05,rely=0.5, relheight=0.08)
        
    User_name= Entry(labelFrame)
    User_name.place(relx=0.3,rely=0.5, relwidth=0.62, relheight=0.08)
    
    
     # password
    Pass= Label(labelFrame,text="Password : ", bg='black', fg='white')
    Pass.place(relx=0.05,rely=0.7, relheight=0.08)
        
    Pass = Entry(labelFrame)
    Pass.place(relx=0.3,rely=0.7, relwidth=0.62, relheight=0.08)
    
    
    submitb=tk.Button(root,text='Sign up',command=insert_user_info)
    submitb.place(relx=0.5,rely=0.83, relwidth=0.4, relheight=0.08)
    
    
    quitb=tk.Button(root,text='Quit',command=root.destroy)
    quitb.place(relx=0.2,rely=0.83, relwidth=0.4, relheight=0.08)
    
def read_output():
    root = tk.Tk()
    root.title("Read")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")



    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="salmon")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="cyan2",bd=5)
    headingFrame1.place(relx=0.25,rely=0.05,relwidth=0.5,relheight=0.10)

    headingLabel = Label(headingFrame1, text="Read Entry", fg='black', font=('Courier',30))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='cyan2')
    labelFrame.place(relx=0.1,rely=0.17,relwidth=0.8,relheight=0.7)
    
    y=0.25
    
    password=Passy.get()
    date=datey.get()
    sql = "select date,diary_entry from diary where password=%s"
    val=(password)
    try:
        mycursor.execute(sql,(val,))
        myresult = mycursor.fetchall()
        for x in myresult:
            if(x[0]==date):
                Label(labelFrame, text="%-30s%-3000s"%(x[0],x[1]),bg='cyan2',fg='black').place(relx=0.07,rely=y)
                y += 0.1
            else:
                Label(labelFrame, text="Please check the password/date again",bg='cyan2',fg='black').place(relx=0.07,rely=0.5)
    except:
          messagebox.showinfo("Please check the password/date again")
    
    
    quitb=tk.Button(root,text='Quit',command=root.destroy)
    quitb.place(relx=0.2,rely=0.83, relwidth=0.4, relheight=0.08)
    
    
    
def read():
    
    global Passy, datey,root
    
    root = tk.Tk()
    root.title("Read")
    root.minsize(width=400,height=400)
    root.geometry("1000x600")



    Canvas1 = Canvas(root)
    
    Canvas1.config(bg="salmon")
    Canvas1.pack(expand=True,fill=BOTH)
        
    headingFrame1 = Frame(root,bg="cyan2",bd=5)
    headingFrame1.place(relx=0.25,rely=0.05,relwidth=0.5,relheight=0.10)

    headingLabel = Label(headingFrame1, text="Read Entry", fg='black', font=('Courier',30))
    headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)

    labelFrame = Frame(root,bg='cyan2')
    labelFrame.place(relx=0.1,rely=0.17,relwidth=0.8,relheight=0.7)
    
    #userName
    user= Label(labelFrame,text="User Name : ", bg='black', fg='white')
    user.place(relx=0.05,rely=0.1, relheight=0.08)
        
    user = Entry(labelFrame)
    user.place(relx=0.3,rely=0.1, relwidth=0.62, relheight=0.08)
    
    
     # password
    Passy= Label(labelFrame,text="Password : ", bg='black', fg='white')
    Passy.place(relx=0.05,rely=0.3, relheight=0.08)
        
    Passy= Entry(labelFrame)
    Passy.place(relx=0.3,rely=0.3, relwidth=0.62, relheight=0.08)
    
    
    #date
    datey= Label(labelFrame,text="Date : ", bg='black', fg='white')
    datey.place(relx=0.05,rely=0.5, relheight=0.08)
        
    datey = Entry(labelFrame)
    datey.place(relx=0.3,rely=0.5, relwidth=0.62, relheight=0.08)
    
    
    submitb=tk.Button(root,text='Quit',command=root.destroy)
    submitb.place(relx=0.5,rely=0.83, relwidth=0.4, relheight=0.08)
    
    
    quitb=tk.Button(root,text='Read',command=read_output)
    quitb.place(relx=0.2,rely=0.83, relwidth=0.4, relheight=0.08)

# %%
 #Main
root=tk.Tk()
root.title("My Journal")
root.minsize(width=400,height=400)
root.geometry("1000x600")
 
    
w=Canvas(root)
w.config(background="salmon")
w.pack(expand=True,fill=BOTH)
    
headingFrame1 = Frame(root,bg="cyan2",bd=5)
headingFrame1.place(relx=0.25,rely=0.05,relwidth=0.6,relheight=0.10)

headingLabel = Label(headingFrame1, text="Welcome to the journal", fg='gold', font=('Courier',30))
headingLabel.place(relx=0,rely=0, relwidth=1, relheight=1)
   
button1=tk.Button(root,text='Make New Entry',command=new_ent)
button1.place(relx=0.5,rely=0.3, relwidth=0.4, relheight=0.08)

button2=tk.Button(root,text='Sign up', command=sign_up)
button2.place(relx=0.1,rely=0.3, relwidth=0.4, relheight=0.08)


button3=tk.Button(root,text='Read Entry',command=read)
button3.place(relx=0.1,rely=0.5, relwidth=0.4, relheight=0.08)


button4=tk.Button(root,text='Quit',command=root.destroy)
button4.place(relx=0.5,rely=0.5, relwidth=0.4, relheight=0.08)
mainloop()
